# %% [markdown]
# # Leaflet cluster map of talk locations
#
# Run this from the _talks/ directory, which contains .md files of all your talks. This scrapes the location YAML field from each .md file, geolocates it with geopy/Nominatim, and uses the getorg library to output data, HTML, and Javascript for a standalone cluster map.

# %%
# !pip install getorg --upgrade
import glob
import getorg
from geopy import Nominatim
# Out:
# Collecting getorg
#   Downloading getorg-0.3.1-py2.py3-none-any.whl.metadata (326 bytes)
# Collecting geopy (from getorg)
#   Downloading geopy-2.4.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting pygithub (from getorg)
#   Downloading pygithub-2.8.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting retrying (from getorg)
#   Downloading retrying-1.4.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting geographiclib<3,>=1.52 (from geopy->getorg)
#   Downloading geographiclib-2.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting pynacl>=1.4.0 (from pygithub->getorg)
#   Downloading pynacl-1.6.2-cp38-abi3-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: requests>=2.14.0 in c:\users\saifa\saifaldeenalkadhim.github.io\.venv\lib\site-packages (from pygithub->getorg) (2.32.5)
# Collecting pyjwt>=2.4.0 (from pyjwt[crypto]>=2.4.0->pygithub->getorg)
#   Downloading PyJWT-2.10.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting typing-extensions>=4.5.0 (from pygithub->getorg)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\saifa\saifaldeenalkadhim.github.io\.venv\lib\site-packages (from pygithub->getorg) (2.6.3)
# Collecting cryptography>=3.4.0 (from pyjwt[crypto]>=2.4.0->pygithub->getorg)
#   Downloading cryptography-46.0.3-cp311-abi3-win_amd64.whl.metadata (5.7 kB)
# Collecting cffi>=2.0.0 (from cryptography>=3.4.0->pyjwt[crypto]>=2.4.0->pygithub->getorg)
#   Downloading cffi-2.0.0-cp313-cp313-win_amd64.whl.metadata (2.6 kB)
# Collecting pycparser (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.4.0->pygithub->getorg)
#   Downloading pycparser-2.23-py3-none-any.whl.metadata (993 bytes)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\saifa\saifaldeenalkadhim.github.io\.venv\lib\site-packages (from requests>=2.14.0->pygithub->getorg) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\saifa\saifaldeenalkadhim.github.io\.venv\lib\site-packages (from requests>=2.14.0->pygithub->getorg) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\saifa\saifaldeenalkadhim.github.io\.venv\lib\site-packages (from requests>=2.14.0->pygithub->getorg) (2026.1.4)
# Downloading getorg-0.3.1-py2.py3-none-any.whl (39 kB)
# Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
# Downloading geographiclib-2.1-py3-none-any.whl (40 kB)
# Downloading pygithub-2.8.1-py3-none-any.whl (432 kB)
# Downloading PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Downloading cryptography-46.0.3-cp311-abi3-win_amd64.whl (3.5 MB)
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    ----------- ---------------------------- 1.0/3.5 MB 5.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 2.1/3.5 MB 5.1 MB/s eta 0:00:01
#    -------------------------------- ------- 2.9/3.5 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------- 3.5/3.5 MB 4.4 MB/s  0:00:00
# Downloading cffi-2.0.0-cp313-cp313-win_amd64.whl (183 kB)
# Downloading pynacl-1.6.2-cp38-abi3-win_amd64.whl (239 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading pycparser-2.23-py3-none-any.whl (118 kB)
# Downloading retrying-1.4.2-py3-none-any.whl (10 kB)
# Installing collected packages: typing-extensions, retrying, pyjwt, pycparser, geographiclib, geopy, cffi, pynacl, cryptography, pygithub, getorg
#
#    ------- --------------------------------  2/11 [pyjwt]
#    ------- --------------------------------  2/11 [pyjwt]
#    ---------- -----------------------------  3/11 [pycparser]
#    ---------- -----------------------------  3/11 [pycparser]
#    ---------- -----------------------------  3/11 [pycparser]
#    ---------- -----------------------------  3/11 [pycparser]
#    -------------- -------------------------  4/11 [geographiclib]
#    ------------------ ---------------------  5/11 [geopy]
#    ------------------ ---------------------  5/11 [geopy]
#    ------------------ ---------------------  5/11 [geopy]
#    ------------------ ---------------------  5/11 [geopy]
#    ------------------ ---------------------  5/11 [geopy]
#    ------------------ ---------------------  5/11 [geopy]
#    ------------------ ---------------------  5/11 [geopy]
#    ------------------ ---------------------  5/11 [geopy]
#    --------------------- ------------------  6/11 [cffi]
#    --------------------- ------------------  6/11 [cffi]
#    --------------------- ------------------  6/11 [cffi]
#    --------------------- ------------------  6/11 [cffi]
#    ------------------------- --------------  7/11 [pynacl]
#    ------------------------- --------------  7/11 [pynacl]
#    ------------------------- --------------  7/11 [pynacl]
#    ------------------------- --------------  7/11 [pynacl]
#    ------------------------- --------------  7/11 [pynacl]
#    ----------------------------- ----------  8/11 [cryptography]
#    ----------------------------- ----------  8/11 [cryptography]
#    ----------------------------- ----------  8/11 [cryptography]
#    ----------------------------- ----------  8/11 [cryptography]
#    ----------------------------- ----------  8/11 [cryptography]
#    ----------------------------- ----------  8/11 [cryptography]
#    ----------------------------- ----------  8/11 [cryptography]
#    ----------------------------- ----------  8/11 [cryptography]
#    ----------------------------- ----------  8/11 [cryptography]
#    ----------------------------- ----------  8/11 [cryptography]
#    -------------------------------- -------  9/11 [pygithub]
#    -------------------------------- -------  9/11 [pygithub]
#    -------------------------------- -------  9/11 [pygithub]
#    -------------------------------- -------  9/11 [pygithub]
#    -------------------------------- -------  9/11 [pygithub]
#    -------------------------------- -------  9/11 [pygithub]
#    -------------------------------- -------  9/11 [pygithub]
#    -------------------------------- -------  9/11 [pygithub]
#    -------------------------------- -------  9/11 [pygithub]
#    -------------------------------- -------  9/11 [pygithub]
#    -------------------------------- -------  9/11 [pygithub]
#    -------------------------------- -------  9/11 [pygithub]
#    -------------------------------- -------  9/11 [pygithub]
#    -------------------------------- -------  9/11 [pygithub]
#    -------------------------------- -------  9/11 [pygithub]
#    -------------------------------- -------  9/11 [pygithub]
#    -------------------------------- -------  9/11 [pygithub]
#    -------------------------------- -------  9/11 [pygithub]
#    -------------------------------- -------  9/11 [pygithub]
#    -------------------------------- -------  9/11 [pygithub]
#    -------------------------------- -------  9/11 [pygithub]
#    -------------------------------- -------  9/11 [pygithub]
#    -------------------------------- -------  9/11 [pygithub]
#    -------------------------------- -------  9/11 [pygithub]
#    -------------------------------- -------  9/11 [pygithub]
#    -------------------------------- -------  9/11 [pygithub]
#    -------------------------------- -------  9/11 [pygithub]
#    -------------------------------- -------  9/11 [pygithub]
#    ------------------------------------ --- 10/11 [getorg]
#    ---------------------------------------- 11/11 [getorg]
#
# Successfully installed cffi-2.0.0 cryptography-46.0.3 geographiclib-2.1 geopy-2.4.1 getorg-0.3.1 pycparser-2.23 pygithub-2.8.1 pyjwt-2.10.1 pynacl-1.6.2 retrying-1.4.2 typing-extensions-4.15.0
# Iywidgets and ipyleaflet support disabled. You must be in a Jupyter notebook to use this feature.
# Error raised:
# No module named 'ipywidgets'
# Check that you have enabled ipyleaflet in Jupyter with:
#     jupyter nbextension enable --py ipyleaflet

# %%
g = glob.glob("*.md")

# %%
geocoder = Nominatim()
location_dict = {}
location = ""
permalink = ""
title = ""
# Out:
# ---------------------------------------------------------------------------
# ConfigurationError                        Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 geocoder = Nominatim()
#       2 location_dict = {}
#       3 location = ""
#
# File c:\Users\saifa\SaifaldeenALKADHIM.github.io\.venv\Lib\site-packages\geopy\geocoders\nominatim.py:105, in Nominatim.__init__(self, timeout, proxies, domain, scheme, user_agent, ssl_context, adapter_factory)
#     101 self.domain = domain.strip('/')
#     103 if (self.domain == _DEFAULT_NOMINATIM_DOMAIN
#     104         and self.headers['User-Agent'] in _REJECTED_USER_AGENTS):
# --> 105     raise ConfigurationError(
#     106         'Using Nominatim with default or sample `user_agent` "%s" is '
#     107         'strongly discouraged, as it violates Nominatim\'s ToS '
#     108         'https://operations.osmfoundation.org/policies/nominatim/ '
#     109         'and may possibly cause 403 and 429 HTTP errors. '
#     110         'Please specify a custom `user_agent` with '
#     111         '`Nominatim(user_agent="my-application")` or by '
#     112         'overriding the default `user_agent`: '
#     113         '`geopy.geocoders.options.default_user_agent = "my-application"`.'
#     114         % self.headers['User-Agent']
#     115     )
#     117 self.api = "%s://%s%s" % (self.scheme, self.domain, self.geocode_path)
#     118 self.reverse_api = "%s://%s%s" % (self.scheme, self.domain, self.reverse_path)
#
# ConfigurationError: Using Nominatim with default or sample `user_agent` "geopy/2.4.1" is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`.

# %%
for file in g:
    with open(file, 'r') as f:
        lines = f.read()
        if lines.find('location: "') > 1:
            loc_start = lines.find('location: "') + 11
            lines_trim = lines[loc_start:]
            loc_end = lines_trim.find('"')
            location = lines_trim[:loc_end]
                            
           
        location_dict[location] = geocoder.geocode(location)
        print(location, "\n", location_dict[location])
# Out:
# Berkeley CA, USA
#  Berkeley, Alameda County, California, United States of America
# Los Angeles, CA
#  LA, Los Angeles County, California, United States of America
# London, UK
#  London, Greater London, England, UK
# San Francisco, California
#  SF, California, United States of America

# %%
m = getorg.orgmap.create_map_obj()
getorg.orgmap.output_html_cluster_map(location_dict, folder_name="../talkmap", hashed_usernames=False)
# Out:
# 'Written map to ../talkmap/'
